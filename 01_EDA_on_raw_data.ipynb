# %% [markdown]
# <a href="https://colab.research.google.com/github/liladqa/riskvector/blob/main/01_EDA_on_raw_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. EDA ON RAW DATA**

# %% [markdown]
# # Load

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import zipfile
import os

zip_path = "/content/gdrive/MyDrive/startups.zip"
extract_folder = "/content/rozpakowane"
os.makedirs(extract_folder, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

# %%
import pandas as pd
startups = pd.read_csv("/content/rozpakowane/startup data.csv")

# %% [markdown]
# # Overview

# %%
startups.shape
# Out:
# (923, 49)

# %%
startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                923 non-null    int64
#  1   state_code                923 non-null    object
#  2   latitude                  923 non-null    float64
#  3   longitude                 923 non-null    float64
#  4   zip_code                  923 non-null    object
#  5   id                        923 non-null    object
#  6   city                      923 non-null    object
#  7   Unnamed: 6                430 non-null    object
#  8   name                      923 non-null    object
#  9   labels                    923 non-null    int64
#  10  founded_at                923 non-null    object
#  11  closed_at                 335 non-null    object
#  12  first_funding_at          923 non-null    object
#  13  last_funding_at           923 non-null    object
#  14  age_first_funding_year    923 non-null    float64
#  15  age_last_funding_year     923 non-null    float64
#  16  age_first_milestone_year  771 non-null    float64
#  17  age_last_milestone_year   771 non-null    float64
#  18  relationships             923 non-null    int64
#  19  funding_rounds            923 non-null    int64
#  20  funding_total_usd         923 non-null    int64
#  21  milestones                923 non-null    int64
#  22  state_code.1              922 non-null    object
#  23  is_CA                     923 non-null    int64
#  24  is_NY                     923 non-null    int64
#  25  is_MA                     923 non-null    int64
#  26  is_TX                     923 non-null    int64
#  27  is_otherstate             923 non-null    int64
#  28  category_code             923 non-null    object
#  29  is_software               923 non-null    int64
#  30  is_web                    923 non-null    int64
#  31  is_mobile                 923 non-null    int64
#  32  is_enterprise             923 non-null    int64
#  33  is_advertising            923 non-null    int64
#  34  is_gamesvideo             923 non-null    int64
#  35  is_ecommerce              923 non-null    int64
#  36  is_biotech                923 non-null    int64
#  37  is_consulting             923 non-null    int64
#  38  is_othercategory          923 non-null    int64
#  39  object_id                 923 non-null    object
#  40  has_VC                    923 non-null    int64
#  41  has_angel                 923 non-null    int64
#  42  has_roundA                923 non-null    int64
#  43  has_roundB                923 non-null    int64
#  44  has_roundC                923 non-null    int64
#  45  has_roundD                923 non-null    int64
#  46  avg_participants          923 non-null    float64
#  47  is_top500                 923 non-null    int64
#  48  status                    923 non-null    object
# dtypes: float64(7), int64(28), object(14)
# memory usage: 353.5+ KB

# %%
startups.describe()
# Out:
#         Unnamed: 0    latitude   longitude      labels  \
# count   923.000000  923.000000  923.000000  923.000000
# mean    572.297941   38.517442 -103.539212    0.646804
# std     333.585431    3.741497   22.394167    0.478222
# min       1.000000   25.752358 -122.756956    0.000000
# 25%     283.500000   37.388869 -122.198732    0.000000
# 50%     577.000000   37.779281 -118.374037    1.000000
# 75%     866.500000   40.730646  -77.214731    1.000000
# max    1153.000000   59.335232   18.057121    1.000000
#
#        age_first_funding_year  age_last_funding_year  \
# count              923.000000             923.000000
# mean                 2.235630               3.931456
# std                  2.510449               2.967910
# min                 -9.046600              -9.046600
# 25%                  0.576700               1.669850
# 50%                  1.446600               3.528800
# 75%                  3.575350               5.560250
# max                 21.895900              21.895900
#
#        age_first_milestone_year  age_last_milestone_year  relationships  \
# count                771.000000               771.000000     923.000000
# mean                   3.055353                 4.754423       7.710726
# std                    2.977057                 3.212107       7.265776
# min                  -14.169900                -7.005500       0.000000
# 25%                    1.000000                 2.411000       3.000000
# 50%                    2.520500                 4.476700       5.000000
# 75%                    4.686300                 6.753400      10.000000
# max                   24.684900                24.684900      63.000000
#
#        funding_rounds  ...  is_consulting  is_othercategory      has_VC  \
# count      923.000000  ...     923.000000        923.000000  923.000000
# mean         2.310943  ...       0.003250          0.322860    0.326111
# std          1.390922  ...       0.056949          0.467823    0.469042
# min          1.000000  ...       0.000000          0.000000    0.000000
# 25%          1.000000  ...       0.000000          0.000000    0.000000
# 50%          2.000000  ...       0.000000          0.000000    0.000000
# 75%          3.000000  ...       0.000000          1.000000    1.000000
# max         10.000000  ...       1.000000          1.000000    1.000000
#
#         has_angel  has_roundA  has_roundB  has_roundC  has_roundD  \
# count  923.000000  923.000000  923.000000  923.000000  923.000000
# mean     0.254605    0.508126    0.392199    0.232936    0.099675
# std      0.435875    0.500205    0.488505    0.422931    0.299729
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        avg_participants   is_top500
# count        923.000000  923.000000
# mean           2.838586    0.809317
# std            1.874601    0.393052
# min            1.000000    0.000000
# 25%            1.500000    1.000000
# 50%            2.500000    1.000000
# 75%            3.800000    1.000000
# max           16.000000    1.000000
#
# [8 rows x 35 columns]

# %%
startups.head()
# Out:
#    Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0        1005         CA  42.358880  -71.056820    92101   c:6669
# 1         204         CA  37.238916 -121.973718    95032  c:16283
# 2        1001         CA  32.901049 -117.192656    92121  c:65620
# 3         738         CA  37.320309 -122.050040    95014  c:42668
# 4        1002         CA  37.779281 -122.419236    94105  c:65806
#
#             city              Unnamed: 6               name  labels  ...  \
# 0      San Diego                     NaN        Bandsintown       1  ...
# 1      Los Gatos                     NaN          TriCipher       1  ...
# 2      San Diego      San Diego CA 92121              Plixi       1  ...
# 3      Cupertino      Cupertino CA 95014  Solidcore Systems       1  ...
# 4  San Francisco  San Francisco CA 94105     Inhale Digital       0  ...
#
#   object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 0    c:6669      0         1          0           0           0           0
# 1   c:16283      1         0          0           1           1           1
# 2   c:65620      0         0          1           0           0           0
# 3   c:42668      0         0          0           1           1           1
# 4   c:65806      1         1          0           0           0           0
#
#    avg_participants  is_top500    status
# 0            1.0000          0  acquired
# 1            4.7500          1  acquired
# 2            4.0000          1  acquired
# 3            3.3333          1  acquired
# 4            1.0000          1    closed
#
# [5 rows x 49 columns]

# %%
list(startups.columns)
# Out:
# ['Unnamed: 0',
#  'state_code',
#  'latitude',
#  'longitude',
#  'zip_code',
#  'id',
#  'city',
#  'Unnamed: 6',
#  'name',
#  'labels',
#  'founded_at',
#  'closed_at',
#  'first_funding_at',
#  'last_funding_at',
#  'age_first_funding_year',
#  'age_last_funding_year',
#  'age_first_milestone_year',
#  'age_last_milestone_year',
#  'relationships',
#  'funding_rounds',
#  'funding_total_usd',
#  'milestones',
#  'state_code.1',
#  'is_CA',
#  'is_NY',
#  'is_MA',
#  'is_TX',
#  'is_otherstate',
#  'category_code',
#  'is_software',
#  'is_web',
#  'is_mobile',
#  'is_enterprise',
#  'is_advertising',
#  'is_gamesvideo',
#  'is_ecommerce',
#  'is_biotech',
#  'is_consulting',
#  'is_othercategory',
#  'object_id',
#  'has_VC',
#  'has_angel',
#  'has_roundA',
#  'has_roundB',
#  'has_roundC',
#  'has_roundD',
#  'avg_participants',
#  'is_top500',
#  'status']

# %%
# Column descriptions
"""
'Unnamed: 0' – CSV export artifact (not needed)
'state_code' – US state code
'latitude' – geographic latitude
'longitude' – geographic longitude
'zip_code' – postal code
'id' – company ID in the database
'city' – city
'Unnamed: 6' – CSV export artifact
'name' – company name
'labels' – numeric representation of company status (operating / not operating)
'founded_at' – company founding date
'closed_at' – company closing date
'first_funding_at' – date of first funding
'last_funding_at' – date of last funding
'age_first_funding_year' – company age (in years) at first funding
'age_last_funding_year' – company age (in years) at last funding
'age_first_milestone_year' – company age (in years) at first milestone
'age_last_milestone_year' – company age (in years) at last milestone
'relationships' – number of relationships
'funding_rounds' – number of funding rounds
'funding_total_usd' – total funding amount in USD
'milestones' – number of milestones
'state_code.1' – duplicate state code column
'is_CA' – located in California
'is_NY' – located in New York
'is_MA' – located in Massachusetts
'is_TX' – located in Texas
'is_otherstate' – located in another state
'category_code' – industry category
'is_software' – software company
'is_web' – web-based company
'is_mobile' – mobile company
'is_enterprise' – enterprise company
'is_advertising' – advertising company
'is_gamesvideo' – games/video company
'is_ecommerce' – e-commerce company
'is_biotech' – biotech company
'is_consulting' – consulting company
'is_othercategory' – other industry category
'object_id' – database object ID
'has_VC' – has venture capital investor
'has_angel' – has angel investor
'has_roundA' – reached funding round A
'has_roundB' – reached funding round B
'has_roundC' – reached funding round C
'has_roundD' – reached funding round D
'avg_participants' – average number of participants per funding round
'is_top500' – is among top 500 companies
'status' – company survival status (target variable)

Additional notes from the dataset author:
-> 'age_first_funding_year' is the age of the company (in years) when it received its first funding. The same applies to 'age_last_funding_year'.
-> A milestone for a startup is a progress tracking event, similar to a milestone on a road, indicating how far the startup has progressed in executing its plan.
-> 'relationships' indicates how many relationships a startup has, e.g. with accountants, investors, vendors, mentors, etc.
-> Funding rounds for startups are explained in detail here:
   https://www.forbes.com/sites/alejandrocremades/2018/12/26/how-funding-rounds-work-for-startups/?sh=57858cc73866
"""
# Out:
# "\n'Unnamed: 0' – CSV export artifact (not needed)\n'state_code' – US state code\n'latitude' – geographic latitude\n'longitude' – geographic longitude\n'zip_code' – postal code\n'id' – company ID in the database\n'city' – city\n'Unnamed: 6' – CSV export artifact\n'name' – company name\n'labels' – numeric representation of company status (operating / not operating)\n'founded_at' – company founding date\n'closed_at' – company closing date\n'first_funding_at' – date of first funding\n'last_funding_at' – date of last funding\n'age_first_funding_year' – company age (in years) at first funding\n'age_last_funding_year' – company age (in years) at last funding\n'age_first_milestone_year' – company age (in years) at first milestone\n'age_last_milestone_year' – company age (in years) at last milestone\n'relationships' – number of relationships\n'funding_rounds' – number of funding rounds\n'funding_total_usd' – total funding amount in USD\n'milestones' – number of milestones\n'state_code.1' – duplicate state code column\n'is_CA' – located in California\n'is_NY' – located in New York\n'is_MA' – located in Massachusetts\n'is_TX' – located in Texas\n'is_otherstate' – located in another state\n'category_code' – industry category\n'is_software' – software company\n'is_web' – web-based company\n'is_mobile' – mobile company\n'is_enterprise' – enterprise company\n'is_advertising' – advertising company\n'is_gamesvideo' – games/video company\n'is_ecommerce' – e-commerce company\n'is_biotech' – biotech company\n'is_consulting' – consulting company\n'is_othercategory' – other industry category\n'object_id' – database object ID\n'has_VC' – has venture capital investor\n'has_angel' – has angel investor\n'has_roundA' – reached funding round A\n'has_roundB' – reached funding round B\n'has_roundC' – reached funding round C\n'has_roundD' – reached funding round D\n'avg_participants' – average number of participants per funding round\n'is_top500' – is among top 500 companies\n'status' – company survival status (target variable)\n\nAdditional notes from the dataset author:\n-> 'age_first_funding_year' is the age of the company (in years) when it received its first funding. The same applies to 'age_last_funding_year'.\n-> A milestone for a startup is a progress tracking event, similar to a milestone on a road, indicating how far the startup has progressed in executing its plan.\n-> 'relationships' indicates how many relationships a startup has, e.g. with accountants, investors, vendors, mentors, etc.\n-> Funding rounds for startups are explained in detail here:\n   https://www.forbes.com/sites/alejandrocremades/2018/12/26/how-funding-rounds-work-for-startups/?sh=57858cc73866\n"

# %% [markdown]
# Conclusions:
#
#
# *   Columns Unnamed: 0 and Unnamed: 6 are likely CSV export artifacts and can be dropped later on.

# %% [markdown]
# # Missing data analysis

# %%
startups.isna().sum()

no_of_missing_values = startups.isnull().sum()
percent_missing = round(startups.isnull().sum() * 100 / len(startups), 2)
missing_values_df = pd.DataFrame({
                                 'no_of_missing_values': no_of_missing_values,
                                 'percent_missing': percent_missing})

missing_values_df
# Out:
#                           no_of_missing_values  percent_missing
# Unnamed: 0                                   0             0.00
# state_code                                   0             0.00
# latitude                                     0             0.00
# longitude                                    0             0.00
# zip_code                                     0             0.00
# id                                           0             0.00
# city                                         0             0.00
# Unnamed: 6                                 493            53.41
# name                                         0             0.00
# labels                                       0             0.00
# founded_at                                   0             0.00
# closed_at                                  588            63.71
# first_funding_at                             0             0.00
# last_funding_at                              0             0.00
# age_first_funding_year                       0             0.00
# age_last_funding_year                        0             0.00
# age_first_milestone_year                   152            16.47
# age_last_milestone_year                    152            16.47
# relationships                                0             0.00
# funding_rounds                               0             0.00
# funding_total_usd                            0             0.00
# milestones                                   0             0.00
# state_code.1                                 1             0.11
# is_CA                                        0             0.00
# is_NY                                        0             0.00
# is_MA                                        0             0.00
# is_TX                                        0             0.00
# is_otherstate                                0             0.00
# category_code                                0             0.00
# is_software                                  0             0.00
# is_web                                       0             0.00
# is_mobile                                    0             0.00
# is_enterprise                                0             0.00
# is_advertising                               0             0.00
# is_gamesvideo                                0             0.00
# is_ecommerce                                 0             0.00
# is_biotech                                   0             0.00
# is_consulting                                0             0.00
# is_othercategory                             0             0.00
# object_id                                    0             0.00
# has_VC                                       0             0.00
# has_angel                                    0             0.00
# has_roundA                                   0             0.00
# has_roundB                                   0             0.00
# has_roundC                                   0             0.00
# has_roundD                                   0             0.00
# avg_participants                             0             0.00
# is_top500                                    0             0.00
# status                                       0             0.00

# %% [markdown]
# Observations:
#
#
#
# *   493 NaNs for Unnamed: 6 - contains a high proportion of missing values and appears to be CSV atrifact. This column does not carry any informative value and will be considered for the removal in the data cleaning stage.
# *   588 NaNs for closed_at - the missing entries most likely indicate that these starups were still operating at the time the dataset was recorded.
# *   152 NaNs for age_first_milestone_year - these starups likely didn't reach their first milestone. Therefore this column, as the previous one, is informative and won't be considered for removal.
# *   152 age_last_milestone_year - same as the age_first_milestone_year.
# *   state_code.1 - one missing value, probably due to minor data inconsistency.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 6))
sns.heatmap(startups.isna(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("Missing Values Heatmap — All Columns")
plt.xlabel("Features")
plt.ylabel("Rows")
plt.show()

# %% [markdown]
# # Data consistency & logical errors

# %% [markdown]
# IDs and duplicates

# %%
#check for duplicates
import numpy as np
duplicates = startups.duplicated(keep=False).sum()
print(duplicates)
# Out:
# 0

# %% [markdown]
# No duplicated rows detected.

# %% [markdown]
# Checking if the ID values are unique

# %%
#id check - each id should be unique
unique_ids = startups["id"].is_unique

no_unique = startups["id"].nunique()
no_ids = startups["id"].count()

print(unique_ids, no_unique, no_ids)
# Out:
# False 922 923

# %%
startups[startups["id"].duplicated(keep=False)].sort_values("id")
# Out:
#      Unnamed: 0 state_code  latitude   longitude zip_code       id     city  \
# 124         506         CA  37.54827 -121.988572    94538  c:28482  Fremont
# 832         505         CA  37.48151 -121.945328    94538  c:28482  Fremont
#
#            Unnamed: 6             name  labels  ... object_id has_VC  \
# 124  Fremont CA 94538  Redwood Systems       1  ...   c:28482      1
# 832               NaN  Redwood Systems       1  ...   c:28482      1
#
#     has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 124         0          1           1           1           0
# 832         0          1           1           1           0
#
#      avg_participants  is_top500    status
# 124              2.25          1  acquired
# 832              2.25          1  acquired
#
# [2 rows x 49 columns]

# %% [markdown]
# One duplicated id value was identified, resulting in two associated records which will be addressed during the data cleaning stage.

# %% [markdown]
# Temporal consistency

# %%
"""
check relations between:

founded_at ≤ first_funding_at
first_funding_at ≤ last_funding_at
closed_at ≥ founded_at (if the closed_at is not NaN)
no funding rounds after closed_at


"""
# Out:
# '\ncheck relations between:\n\nfounded_at ≤ first_funding_at\nfirst_funding_at ≤ last_funding_at\nclosed_at ≥ founded_at (if the closed_at is not NaN)\nno funding rounds after closed_at\n\n\n'

# %%
# checking if founded_at ≤ first_funding_at

#make sure column values are in the date format
startups["founded_at"] = pd.to_datetime(startups["founded_at"], errors="coerce")
startups["first_funding_at"] = pd.to_datetime(startups["first_funding_at"], errors="coerce")

non_null = startups["first_funding_at"].notna() & startups["founded_at"].notna()
temporal_validation = startups["first_funding_at"] > startups["founded_at"]

violations = startups[non_null & temporal_validation]
violations
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0          1005         CA  42.358880  -71.056820    92101   c:6669
# 1           204         CA  37.238916 -121.973718    95032  c:16283
# 2          1001         CA  32.901049 -117.192656    92121  c:65620
# 3           738         CA  37.320309 -122.050040    95014  c:42668
# 5           379         CA  37.406914 -122.090370    94043  c:22898
# ..          ...        ...        ...         ...      ...      ...
# 918         352         CA  37.740594 -122.376471    94107  c:21343
# 919         721         MA  42.504817  -71.195611     1803  c:41747
# 920         557         CA  37.408261 -122.015920    94089  c:31549
# 921         589         CA  37.556732 -122.288378    94404  c:33198
# 922         462         CA  37.386778 -121.966277    95054  c:26702
#
#               city              Unnamed: 6                  name  labels  ...  \
# 0        San Diego                     NaN           Bandsintown       1  ...
# 1        Los Gatos                     NaN             TriCipher       1  ...
# 2        San Diego      San Diego CA 92121                 Plixi       1  ...
# 3        Cupertino      Cupertino CA 95014     Solidcore Systems       1  ...
# 5    Mountain View  Mountain View CA 94043      Matisse Networks       0  ...
# ..             ...                     ...                   ...     ...  ...
# 918  San Francisco                     NaN               CoTweet       1  ...
# 919     Burlington      Burlington MA 1803    Reef Point Systems       0  ...
# 920      Sunnyvale                     NaN       Paracor Medical       0  ...
# 921  San Francisco                     NaN               Causata       1  ...
# 922    Santa Clara    Santa Clara CA 95054  Asempra Technologies       1  ...
#
#     object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 0      c:6669      0         1          0           0           0           0
# 1     c:16283      1         0          0           1           1           1
# 2     c:65620      0         0          1           0           0           0
# 3     c:42668      0         0          0           1           1           1
# 5     c:22898      0         0          0           1           0           0
# ..        ...    ...       ...        ...         ...         ...         ...
# 918   c:21343      0         0          1           0           0           0
# 919   c:41747      1         0          0           1           0           0
# 920   c:31549      0         0          0           0           0           1
# 921   c:33198      0         0          1           1           0           0
# 922   c:26702      0         0          0           1           0           0
#
#      avg_participants  is_top500    status
# 0              1.0000          0  acquired
# 1              4.7500          1  acquired
# 2              4.0000          1  acquired
# 3              3.3333          1  acquired
# 5              3.0000          1    closed
# ..                ...        ...       ...
# 918            6.0000          1  acquired
# 919            2.6667          1    closed
# 920            8.0000          1    closed
# 921            1.0000          1  acquired
# 922            3.0000          1  acquired
#
# [821 rows x 49 columns]

# %% [markdown]
# The majority of records with non-missing values satisfy the condition first_funding_at > founded_at, suggesting that funding timelines are largly temporally coherent.

# %%
#checking if first_funding_at ≤ last_funding_at

startups["first_funding_at"] = pd.to_datetime(startups["first_funding_at"], errors="coerce")
startups["last_funding_at"] = pd.to_datetime(startups["last_funding_at"], errors="coerce")

non_null = startups["first_funding_at"].notna() & startups["last_funding_at"].notna()

temporal_validation2 = startups["last_funding_at"] >= startups["first_funding_at"]

valid_records = startups[non_null & temporal_validation2]
valid_records
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0          1005         CA  42.358880  -71.056820    92101   c:6669
# 1           204         CA  37.238916 -121.973718    95032  c:16283
# 2          1001         CA  32.901049 -117.192656    92121  c:65620
# 3           738         CA  37.320309 -122.050040    95014  c:42668
# 4          1002         CA  37.779281 -122.419236    94105  c:65806
# ..          ...        ...        ...         ...      ...      ...
# 918         352         CA  37.740594 -122.376471    94107  c:21343
# 919         721         MA  42.504817  -71.195611     1803  c:41747
# 920         557         CA  37.408261 -122.015920    94089  c:31549
# 921         589         CA  37.556732 -122.288378    94404  c:33198
# 922         462         CA  37.386778 -121.966277    95054  c:26702
#
#               city              Unnamed: 6                  name  labels  ...  \
# 0        San Diego                     NaN           Bandsintown       1  ...
# 1        Los Gatos                     NaN             TriCipher       1  ...
# 2        San Diego      San Diego CA 92121                 Plixi       1  ...
# 3        Cupertino      Cupertino CA 95014     Solidcore Systems       1  ...
# 4    San Francisco  San Francisco CA 94105        Inhale Digital       0  ...
# ..             ...                     ...                   ...     ...  ...
# 918  San Francisco                     NaN               CoTweet       1  ...
# 919     Burlington      Burlington MA 1803    Reef Point Systems       0  ...
# 920      Sunnyvale                     NaN       Paracor Medical       0  ...
# 921  San Francisco                     NaN               Causata       1  ...
# 922    Santa Clara    Santa Clara CA 95054  Asempra Technologies       1  ...
#
#     object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 0      c:6669      0         1          0           0           0           0
# 1     c:16283      1         0          0           1           1           1
# 2     c:65620      0         0          1           0           0           0
# 3     c:42668      0         0          0           1           1           1
# 4     c:65806      1         1          0           0           0           0
# ..        ...    ...       ...        ...         ...         ...         ...
# 918   c:21343      0         0          1           0           0           0
# 919   c:41747      1         0          0           1           0           0
# 920   c:31549      0         0          0           0           0           1
# 921   c:33198      0         0          1           1           0           0
# 922   c:26702      0         0          0           1           0           0
#
#      avg_participants  is_top500    status
# 0              1.0000          0  acquired
# 1              4.7500          1  acquired
# 2              4.0000          1  acquired
# 3              3.3333          1  acquired
# 4              1.0000          1    closed
# ..                ...        ...       ...
# 918            6.0000          1  acquired
# 919            2.6667          1    closed
# 920            8.0000          1    closed
# 921            1.0000          1  acquired
# 922            3.0000          1  acquired
#
# [923 rows x 49 columns]

# %% [markdown]
# The resulting table contains the same number of rows as the source dataset, indicating that all records with non-missing funding dates satisfy the condition last_funding_at >= first_funding_at.

# %% [markdown]
# Age columns vs dates consistency

# %%
"""

checking for negative values in time/age-related columns
age_first_funding_year
age_last_funding_year
age_first_milestone_year
age_last_milestone_year

"""
# Out:
# '\n\nchecking for negative values in time/age-related columns\nage_first_funding_year\nage_last_funding_year\nage_first_milestone_year\nage_last_milestone_year\n\n'

# %%
#checking for negative values
is_negative = (startups["age_first_funding_year"] < 0).sum()
print(is_negative)

is_negative_check = startups[startups["age_first_funding_year"] < 0]
is_negative_check
# Out:
# 46
#      Unnamed: 0 state_code   latitude   longitude zip_code        id  \
# 23           26         CA  37.764395 -122.401024    94103   c:10751
# 32          485         NC  36.002893  -78.904075    27701   c:27741
# 71          315         CA  37.349210 -122.032602    94087  c:190214
# 79          555         MA  42.375100  -71.105616     2138   c:31514
# 80          943         CA  37.779281 -122.419236    94105   c:58944
# 104         811         CA  37.748676 -122.415813    94110    c:4622
# 122         615         TX  40.694599  -73.990638    78701    c:3505
# 127         550         PA  40.441694  -79.990086    15213   c:31294
# 234        1032         CA  37.465645 -121.932202    94538      c:72
# 240         529         CA  37.406914 -122.090370    94043   c:30173
# 263         891         UT  40.767013 -111.890431    84124   c:53831
# 284          88         CA  37.448944 -122.161415    94301   c:13358
# 312         526         CA  37.778613 -122.395289    94107      c:30
# 340        1113         CA  37.388077 -122.083160    94041      c:86
# 368         862         CA  33.685697 -117.825982    92612   c:51021
# 379         377         MA  42.360253  -71.058291     2114    c:2275
# 382         869         CA  37.779281 -122.419236    94103   c:51332
# 397          18         NY  37.809782 -122.417306    10003     c:105
# 407         104         NY  40.729839  -73.991781    10003    c:1388
# 420         585         CA  32.889450 -117.166929    92121    c:3267
# 431         886         CA  34.066697 -118.383367    90211   c:53304
# 432         314         CT  54.983201   -1.574631     6103    c:1899
# 466         482         CA  37.775206 -122.419209    94107   c:27591
# 488         468         CA  37.387845 -122.055197    94089      c:27
# 489         325         CA  37.550954 -122.315396    94303    c:1957
# 499         600         CA  37.437328 -122.159928    94303    c:3400
# 513         545         NY  40.743808  -73.983626    10010    c:3094
# 518        1035         CA  37.563585 -122.324621    94043     c:726
# 536          69         WA  47.603327 -122.334983    98104    c:1253
# 558         372         NY  40.743662  -73.984268    10016    c:2245
# 566         968         KY  38.046407  -84.497039    40507   c:60521
# 567         839         CA  37.814202 -122.477959    94025    c:4881
# 584        1017         MA  42.358956  -71.054776     2109    c:6964
# 603         990         CA  37.779281 -122.419236    94105   c:63731
# 609         499         CA  37.406302 -122.108874    94040   c:28403
# 702         118         DC  38.894955  -77.036646    20005  c:144631
# 720         880         TX  30.280148  -97.749908    78701   c:52406
# 763         870         CA  37.779281 -122.419236    94110   c:51379
# 782         826         UT  40.233844 -111.658534    84087   c:47341
# 785         830         NY  40.759089  -73.987573    10036   c:47662
# 788         101         CA  34.144926 -118.149767    91105   c:13815
# 830         711         CA  37.779281 -122.419236    94111   c:41006
# 831         488         NY  40.707645  -74.010816    10038   c:27938
# 847         133         RI  41.818712  -71.411775     2903  c:148566
# 851         857         CA  37.779281 -122.419236    94107   c:50449
# 875         591         MA  42.375100  -71.105616     2139   c:33416
#
#                city               Unnamed: 6                 name  labels  \
# 23    San Francisco                      NaN            Pixelpipe       0
# 32           Durham                      NaN               eMinor       0
# 71        Sunnyvale                      NaN              Behavio       1
# 79        Cambridge        Cambridge MA 2138            AccelGolf       0
# 80    San Francisco   San Francisco CA 94105                MoPub       1
# 104   San Francisco                      NaN             Aardvark       1
# 122          Austin                      NaN         Workstreamer       0
# 127      Pittsburgh      Pittsburgh PA 15213                Bueda       0
# 234         Fremont                      NaN         GrandCentral       1
# 240   Mountain View   Mountain View CA 94043                 UpMo       0
# 263  Salt Lake City  Salt Lake City UT 84124               Inaura       0
# 284       Palo Alto                      NaN              Q-magic       0
# 312   San Francisco                      NaN             Powerset       1
# 340   Mountain View                      NaN         Zing Systems       1
# 368          Irvine          Irvine CA 92612             PayDivvy       1
# 379          Boston           Boston MA 2114                Where       1
# 382   San Francisco   San Francisco CA 94103              Storify       1
# 397        New York                      NaN             Surphace       1
# 407        New York        New York NY 10003  The Huffington Post       1
# 420       San Diego                      NaN       Tapioca Mobile       0
# 431   Beverly Hills   Beverly Hills CA 90211           GeekStatus       0
# 432        Hartford         Hartford CT 6103                 MOLI       0
# 466   San Francisco                      NaN             threadsy       1
# 488       Sunnyvale                      NaN                Plaxo       1
# 489       Palo Alto                      NaN          Sharetivity       0
# 499       Palo Alto                      NaN           MyMiniLife       1
# 513        New York                      NaN    Next New Networks       1
# 518   Mountain View                      NaN                AdMob       1
# 536         Seattle                      NaN                Faves       0
# 558        New York                      NaN            Advaliant       0
# 566       Lexington       Lexington KY 40507         AwesomeTouch       1
# 567      Menlo Park                      NaN          Syncplicity       1
# 584          Boston                      NaN        Swaptree Inc.       0
# 603   San Francisco   San Francisco CA 94105          Weatherista       0
# 609   Mountain View                      NaN         HighlightCam       0
# 702      Washington      Washington DC 20005   VeteranCentral.com       0
# 720          Austin          Austin TX 78701         MapMyFitness       1
# 763   San Francisco   San Francisco CA 94110         1000memories       1
# 782           Provo           Provo UT 84087       Tipping Bucket       0
# 785        New York        New York NY 10036           SpinTheCam       0
# 788        Pasadena                      NaN              iChange       1
# 830   San Francisco   San Francisco CA 94111              Cohuman       1
# 831        New York                      NaN             Correlix       0
# 847      Providence                      NaN   MoveableCode, Inc.       0
# 851   San Francisco   San Francisco CA 94107                 Opzi       0
# 875       Cambridge        Cambridge MA 2139         Bluefin Labs       1
#
#      ... object_id has_VC has_angel has_roundA  has_roundB  has_roundC  \
# 23   ...   c:10751      0         1          1           0           0
# 32   ...   c:27741      0         0          1           1           0
# 71   ...  c:190214      0         1          0           0           0
# 79   ...   c:31514      1         1          0           0           0
# 80   ...   c:58944      0         1          1           1           0
# 104  ...    c:4622      0         1          1           0           0
# 122  ...    c:3505      0         1          1           0           0
# 127  ...   c:31294      1         1          0           0           0
# 234  ...      c:72      0         0          1           0           0
# 240  ...   c:30173      1         0          0           0           0
# 263  ...   c:53831      1         0          0           0           0
# 284  ...   c:13358      0         1          0           0           0
# 312  ...      c:30      1         0          1           0           0
# 340  ...      c:86      0         0          1           0           1
# 368  ...   c:51021      0         1          0           0           0
# 379  ...    c:2275      0         0          1           1           1
# 382  ...   c:51332      0         1          1           0           0
# 397  ...     c:105      0         0          1           1           0
# 407  ...    c:1388      1         0          1           1           1
# 420  ...    c:3267      1         1          0           0           0
# 431  ...   c:53304      0         1          0           0           0
# 432  ...    c:1899      0         0          1           1           0
# 466  ...   c:27591      0         0          1           1           0
# 488  ...      c:27      0         0          1           1           1
# 489  ...    c:1957      0         0          0           0           0
# 499  ...    c:3400      0         1          0           0           0
# 513  ...    c:3094      0         0          1           1           1
# 518  ...     c:726      0         0          1           1           1
# 536  ...    c:1253      0         0          0           0           0
# 558  ...    c:2245      0         1          0           0           0
# 566  ...   c:60521      0         1          0           0           0
# 567  ...    c:4881      0         0          1           0           0
# 584  ...    c:6964      1         0          0           1           1
# 603  ...   c:63731      0         1          0           0           0
# 609  ...   c:28403      0         1          1           0           0
# 702  ...  c:144631      0         1          0           0           0
# 720  ...   c:52406      1         0          1           1           1
# 763  ...   c:51379      0         1          1           0           0
# 782  ...   c:47341      0         1          0           0           0
# 785  ...   c:47662      0         1          0           0           0
# 788  ...   c:13815      0         1          1           0           0
# 830  ...   c:41006      0         1          0           0           0
# 831  ...   c:27938      1         0          0           1           0
# 847  ...  c:148566      0         1          0           0           0
# 851  ...   c:50449      0         1          0           0           0
# 875  ...   c:33416      0         1          1           1           0
#
#      has_roundD  avg_participants  is_top500    status
# 23            0            2.0000          0    closed
# 32            0            2.5000          1    closed
# 71            0            1.0000          0  acquired
# 79            0            1.0000          1    closed
# 80            0            2.2500          1  acquired
# 104           0            4.0000          1  acquired
# 122           0            1.0000          1    closed
# 127           0            1.0000          1    closed
# 234           0            1.0000          0  acquired
# 240           0            3.0000          0    closed
# 263           0            1.0000          0    closed
# 284           0            1.0000          0    closed
# 312           0            4.0000          1  acquired
# 340           0            2.5000          1  acquired
# 368           0            1.0000          0  acquired
# 379           0            2.5000          1  acquired
# 382           0            1.3333          1  acquired
# 397           0            5.5000          1  acquired
# 407           0            2.5000          1  acquired
# 420           0            1.0000          1    closed
# 431           0            1.0000          0    closed
# 432           0            2.0000          0    closed
# 466           0            2.0000          1  acquired
# 488           1            2.5000          1  acquired
# 489           0            1.0000          0    closed
# 499           0            1.6667          0  acquired
# 513           0            3.5000          1  acquired
# 518           0            2.5000          1  acquired
# 536           0            3.0000          0    closed
# 558           0            1.0000          0    closed
# 566           0            1.0000          1  acquired
# 567           0            2.0000          1  acquired
# 584           0            1.0000          1    closed
# 603           0            1.0000          0    closed
# 609           0            3.5000          1    closed
# 702           0            1.0000          0    closed
# 720           0            1.7500          1  acquired
# 763           0            5.0000          1  acquired
# 782           0            1.0000          0    closed
# 785           0            1.0000          0    closed
# 788           0            2.0000          0  acquired
# 830           0            3.0000          0  acquired
# 831           0            3.0000          1    closed
# 847           0            1.0000          1    closed
# 851           0            5.0000          1    closed
# 875           0            3.7500          1  acquired
#
# [46 rows x 49 columns]

# %% [markdown]
# 46 records contain negative values in age_first_funding_yeat columnn which is logically incorrect.

# %%
#checking for negative values in the age_last_funding_year column
is_negative = (startups["age_last_funding_year"] < 0).sum()
print(is_negative)

is_negative_check = startups[startups["age_last_funding_year"] < 0]
is_negative_check
# Out:
# 13
#      Unnamed: 0 state_code   latitude   longitude zip_code        id  \
# 71          315         CA  37.349210 -122.032602    94087  c:190214
# 234        1032         CA  37.465645 -121.932202    94538      c:72
# 263         891         UT  40.767013 -111.890431    84124   c:53831
# 284          88         CA  37.448944 -122.161415    94301   c:13358
# 340        1113         CA  37.388077 -122.083160    94041      c:86
# 431         886         CA  34.066697 -118.383367    90211   c:53304
# 489         325         CA  37.550954 -122.315396    94303    c:1957
# 536          69         WA  47.603327 -122.334983    98104    c:1253
# 558         372         NY  40.743662  -73.984268    10016    c:2245
# 567         839         CA  37.814202 -122.477959    94025    c:4881
# 603         990         CA  37.779281 -122.419236    94105   c:63731
# 702         118         DC  38.894955  -77.036646    20005  c:144631
# 785         830         NY  40.759089  -73.987573    10036   c:47662
#
#                city               Unnamed: 6                name  labels  ...  \
# 71        Sunnyvale                      NaN             Behavio       1  ...
# 234         Fremont                      NaN        GrandCentral       1  ...
# 263  Salt Lake City  Salt Lake City UT 84124              Inaura       0  ...
# 284       Palo Alto                      NaN             Q-magic       0  ...
# 340   Mountain View                      NaN        Zing Systems       1  ...
# 431   Beverly Hills   Beverly Hills CA 90211          GeekStatus       0  ...
# 489       Palo Alto                      NaN         Sharetivity       0  ...
# 536         Seattle                      NaN               Faves       0  ...
# 558        New York                      NaN           Advaliant       0  ...
# 567      Menlo Park                      NaN         Syncplicity       1  ...
# 603   San Francisco   San Francisco CA 94105         Weatherista       0  ...
# 702      Washington      Washington DC 20005  VeteranCentral.com       0  ...
# 785        New York        New York NY 10036          SpinTheCam       0  ...
#
#     object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 71   c:190214      0         1          0           0           0           0
# 234      c:72      0         0          1           0           0           0
# 263   c:53831      1         0          0           0           0           0
# 284   c:13358      0         1          0           0           0           0
# 340      c:86      0         0          1           0           1           0
# 431   c:53304      0         1          0           0           0           0
# 489    c:1957      0         0          0           0           0           0
# 536    c:1253      0         0          0           0           0           0
# 558    c:2245      0         1          0           0           0           0
# 567    c:4881      0         0          1           0           0           0
# 603   c:63731      0         1          0           0           0           0
# 702  c:144631      0         1          0           0           0           0
# 785   c:47662      0         1          0           0           0           0
#
#      avg_participants  is_top500    status
# 71                1.0          0  acquired
# 234               1.0          0  acquired
# 263               1.0          0    closed
# 284               1.0          0    closed
# 340               2.5          1  acquired
# 431               1.0          0    closed
# 489               1.0          0    closed
# 536               3.0          0    closed
# 558               1.0          0    closed
# 567               2.0          1  acquired
# 603               1.0          0    closed
# 702               1.0          0    closed
# 785               1.0          0    closed
#
# [13 rows x 49 columns]

# %% [markdown]
# 13 rows contain negative values in the age_last_funding_year column which is logically incorrect and will be addressed during the data cleaning stage.

# %%
#check for negative values in the age_first_milestone_year column

is_negative = (startups["age_first_milestone_year"] < 0).sum()
print(is_negative)

is_negative_check = startups[startups["age_first_milestone_year"] < 0]
is_negative_check
# Out:
# 46
#      Unnamed: 0 state_code   latitude   longitude    zip_code        id  \
# 11          835         CA  37.452992 -122.185098       94025    c:4829
# 17           25         CA  37.590339 -122.341715       94010     c:107
# 60          617         MA  42.546483  -71.173667        1887   c:35157
# 122         615         TX  40.694599  -73.990638       78701    c:3505
# 123         925         NY  40.729839  -73.991781       10003   c:56989
# 128         764         VA  38.958402  -77.357974       20191   c:43875
# 132          58         CA  37.559110 -122.303493       95054   c:12173
# 234        1032         CA  37.465645 -121.932202       94538      c:72
# 240         529         CA  37.406914 -122.090370       94043   c:30173
# 248          27         OR  45.520247 -122.674195       97209  c:107746
# 257        1016         RI  51.432470   -2.664213        2903   c:69279
# 276         996         NY  40.750519  -73.993494       10001   c:64959
# 340        1113         CA  37.388077 -122.083160       94041      c:86
# 350         455         MI  42.813865  -86.023846       49464   c:26390
# 363         298         CA  38.885210  -76.998641       94107   c:18056
# 368         862         CA  33.685697 -117.825982       92612   c:51021
# 371         829         MA  42.504817  -71.195611        1803   c:47601
# 422        1130         WA  47.598968 -122.332904       98104    c:9085
# 429         583         MA  42.360253  -71.058291        2111   c:32383
# 432         314         CT  54.983201   -1.574631        6103    c:1899
# 439         972         CA  38.223032 -122.261642       94558    c:6150
# 470         564         CA  37.391727 -122.077597       94041    c:3180
# 499         600         CA  37.437328 -122.159928       94303    c:3400
# 542         253         CA  37.496904 -122.333057       94404   c:17252
# 549         909         MA  42.479262  -71.152277        1801   c:55354
# 552         773         CA  37.288326 -121.945633  95008-2069   c:44268
# 558         372         NY  40.743662  -73.984268       10016    c:2245
# 579         328         TX  30.384453  -97.709809       78746    c:1967
# 584        1017         MA  42.358956  -71.054776        2109    c:6964
# 596        1053         DC  38.894955  -77.036646       20009   c:76102
# 597        1064         NY  40.729839  -73.991781       10003   c:76765
# 618         581         WA  45.630695 -122.674456       98665   c:32144
# 627         266         CA  37.377787 -122.029217       94086   c:17508
# 710        1071         CA  34.102827 -118.329990       90028   c:79089
# 716         184         VA  39.050108  -77.400820       20165    c:1607
# 735         324         WA  47.625740 -122.358162       98119   c:19538
# 770         749         NY  40.729839  -73.991781       10003   c:43263
# 791         775         WA  47.682233 -122.135521       98052     c:444
# 802        1109         WA  47.578174 -122.212731       98006    c:8527
# 811         460         CA  37.249635 -121.966593       95008   c:26666
# 823         416         MA  42.337037  -71.251748        2466    c:2478
# 840         669         CA  37.755068 -122.418026       94110   c:38337
# 853           9         IL  41.916619  -87.686634       60647   c:10199
# 857          45         CA  37.761102 -122.416001       94110   c:11498
# 861         477         CA  37.556843 -122.288488       94404   c:27339
# 905         442         CA  37.336191 -121.890583       95110   c:25756
#
#               city              Unnamed: 6                     name  labels  \
# 11      Menlo Park                     NaN                 Center'd       0
# 17      Burlingame                     NaN                   MeeVee       1
# 60      Wilmington      Wilmington MA 1887                   Viacor       0
# 122         Austin                     NaN             Workstreamer       0
# 123       New York       New York NY 10003                    Qwiki       1
# 128         Reston         Reston VA 20191                 Defywire       0
# 132    Santa Clara                     NaN                 Sentrigo       1
# 234        Fremont                     NaN             GrandCentral       1
# 240  Mountain View  Mountain View CA 94043                     UpMo       0
# 248       Portland       Portland OR 97209                 Meridian       1
# 257     Providence      Providence RI 2903              Tracelytics       1
# 276       New York       New York NY 10001           Visual Revenue       1
# 340  Mountain View                     NaN             Zing Systems       1
# 350        Zeeland                     NaN                  Revetto       0
# 363  San Francisco                     NaN                Socialize       1
# 368         Irvine         Irvine CA 92612                 PayDivvy       1
# 371     Burlington      Burlington MA 1803        Airwide Solutions       1
# 422        Seattle                     NaN          Local Marketers       0
# 429         Boston          Boston MA 2111                     Goby       1
# 432       Hartford        Hartford CT 6103                     MOLI       0
# 439           Napa                     NaN   Inertia Beverage Group       0
# 470  Mountain View                     NaN                 Krillion       1
# 499      Palo Alto                     NaN               MyMiniLife       1
# 542      San Mateo      San Mateo CA 94404                D2C Games       0
# 549         Woburn          Woburn MA 1801              WAY Systems       1
# 552       Campbell  Campbell CA 95008-2069                   Forrst       1
# 558       New York                     NaN                Advaliant       0
# 579         Austin                     NaN    BreakingPoint Systems       1
# 584         Boston                     NaN            Swaptree Inc.       0
# 596     Washington     Washington DC 20009            NationalField       1
# 597       New York       New York NY 10003                    Tripl       0
# 618      Vancouver      Vancouver WA 98665                  Idooble       0
# 627      Sunnyvale                     NaN      Mobius Microsystems       1
# 710      Hollywood      Hollywood CA 90028           HelpMeRent.com       0
# 716  Potomac Falls  Potomac Falls VA 20165                  Summize       1
# 735        Seattle                     NaN                 Kashless       0
# 770       New York       New York NY 10003                Feedtrace       1
# 791        Redmond                     NaN                    Sampa       0
# 802       Bellevue                     NaN          Napera Networks       1
# 811       Campbell                     NaN  Anchor Bay Technologies       1
# 823         Newton                     NaN          JackPot Rewards       0
# 840  San Francisco                     NaN                 about.me       1
# 853        Chicago                     NaN          Where I've Been       1
# 857  San Francisco                     NaN                 WeAre.Us       0
# 861      San Mateo                     NaN                   Aptana       1
# 905       San Jose       San Jose CA 95110        Broadway Networks       0
#
#      ... object_id has_VC has_angel has_roundA  has_roundB  has_roundC  \
# 11   ...    c:4829      1         1          1           0           0
# 17   ...     c:107      0         0          1           1           1
# 60   ...   c:35157      0         0          0           1           0
# 122  ...    c:3505      0         1          1           0           0
# 123  ...   c:56989      1         0          1           0           0
# 128  ...   c:43875      1         0          0           1           0
# 132  ...   c:12173      0         0          1           1           1
# 234  ...      c:72      0         0          1           0           0
# 240  ...   c:30173      1         0          0           0           0
# 248  ...  c:107746      1         1          0           0           0
# 257  ...   c:69279      0         1          1           0           0
# 276  ...   c:64959      0         1          1           0           0
# 340  ...      c:86      0         0          1           0           1
# 350  ...   c:26390      0         1          0           0           0
# 363  ...   c:18056      0         1          0           0           0
# 368  ...   c:51021      0         1          0           0           0
# 371  ...   c:47601      0         0          0           0           0
# 422  ...    c:9085      1         0          0           0           0
# 429  ...   c:32383      0         0          1           0           0
# 432  ...    c:1899      0         0          1           1           0
# 439  ...    c:6150      1         0          0           1           0
# 470  ...    c:3180      0         0          1           0           0
# 499  ...    c:3400      0         1          0           0           0
# 542  ...   c:17252      0         0          1           0           0
# 549  ...   c:55354      0         0          0           0           1
# 552  ...   c:44268      0         1          0           0           0
# 558  ...    c:2245      0         1          0           0           0
# 579  ...    c:1967      1         0          0           0           1
# 584  ...    c:6964      1         0          0           1           1
# 596  ...   c:76102      1         0          0           0           0
# 597  ...   c:76765      0         1          0           0           0
# 618  ...   c:32144      0         1          0           0           0
# 627  ...   c:17508      0         0          1           1           0
# 710  ...   c:79089      0         1          0           0           0
# 716  ...    c:1607      0         1          0           0           0
# 735  ...   c:19538      1         0          1           0           0
# 770  ...   c:43263      0         1          0           0           0
# 791  ...     c:444      0         1          0           0           0
# 802  ...    c:8527      0         0          1           0           0
# 811  ...   c:26666      1         0          1           0           0
# 823  ...    c:2478      0         0          1           0           0
# 840  ...   c:38337      1         0          0           0           0
# 853  ...   c:10199      1         1          0           0           0
# 857  ...   c:11498      0         1          0           0           0
# 861  ...   c:27339      1         0          0           0           0
# 905  ...   c:25756      1         0          0           0           0
#
#      has_roundD  avg_participants  is_top500    status
# 11            0            1.7500          1    closed
# 17            1            3.5000          1  acquired
# 60            0            2.0000          1    closed
# 122           0            1.0000          1    closed
# 123           0            6.3333          1  acquired
# 128           0            3.0000          1    closed
# 132           0            2.0000          1  acquired
# 234           0            1.0000          0  acquired
# 240           0            3.0000          0    closed
# 248           0            3.0000          0  acquired
# 257           0            4.0000          1  acquired
# 276           0            3.0000          1  acquired
# 340           0            2.5000          1  acquired
# 350           0            1.0000          0    closed
# 363           0            1.0000          0  acquired
# 368           0            1.0000          0  acquired
# 371           1            5.0000          1  acquired
# 422           0            1.0000          1    closed
# 429           0            2.0000          1  acquired
# 432           0            2.0000          0    closed
# 439           0            2.5000          1    closed
# 470           0            2.0000          1  acquired
# 499           0            1.6667          0  acquired
# 542           0            1.0000          0    closed
# 549           0            4.0000          1  acquired
# 552           0            7.0000          1  acquired
# 558           0            1.0000          0    closed
# 579           0            2.0000          1  acquired
# 584           0            1.0000          1    closed
# 596           0            2.0000          0  acquired
# 597           0            1.5000          1    closed
# 618           0            1.0000          0    closed
# 627           0            3.0000          1  acquired
# 710           0            1.0000          0    closed
# 716           0            2.0000          1  acquired
# 735           0            1.0000          1    closed
# 770           0            1.0000          0  acquired
# 791           0            1.0000          0    closed
# 802           0            1.0000          1  acquired
# 811           0            3.0000          1  acquired
# 823           0            4.0000          0    closed
# 840           0            4.0000          1  acquired
# 853           0            1.0000          1  acquired
# 857           0            3.0000          0    closed
# 861           0            2.0000          1  acquired
# 905           0            1.0000          0    closed
#
# [46 rows x 49 columns]

# %% [markdown]
# 46 values in the column "age_first_milestone_year" contain negative value and will be addressed during the data cleaning stage.

# %%
#check for the negative values in the age_last_milestone_year column

is_negative = (startups["age_last_milestone_year"] < 0).sum()
print(is_negative)

is_negative_check = startups[startups["age_last_milestone_year"] < 0]
is_negative_check
# Out:
# 12
#      Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 60          617         MA  42.546483  -71.173667     1887  c:35157
# 128         764         VA  38.958402  -77.357974    20191  c:43875
# 350         455         MI  42.813865  -86.023846    49464  c:26390
# 371         829         MA  42.504817  -71.195611     1803  c:47601
# 542         253         CA  37.496904 -122.333057    94404  c:17252
# 558         372         NY  40.743662  -73.984268    10016   c:2245
# 579         328         TX  30.384453  -97.709809    78746   c:1967
# 618         581         WA  45.630695 -122.674456    98665  c:32144
# 627         266         CA  37.377787 -122.029217    94086  c:17508
# 811         460         CA  37.249635 -121.966593    95008  c:26666
# 840         669         CA  37.755068 -122.418026    94110  c:38337
# 905         442         CA  37.336191 -121.890583    95110  c:25756
#
#               city          Unnamed: 6                     name  labels  ...  \
# 60      Wilmington  Wilmington MA 1887                   Viacor       0  ...
# 128         Reston     Reston VA 20191                 Defywire       0  ...
# 350        Zeeland                 NaN                  Revetto       0  ...
# 371     Burlington  Burlington MA 1803        Airwide Solutions       1  ...
# 542      San Mateo  San Mateo CA 94404                D2C Games       0  ...
# 558       New York                 NaN                Advaliant       0  ...
# 579         Austin                 NaN    BreakingPoint Systems       1  ...
# 618      Vancouver  Vancouver WA 98665                  Idooble       0  ...
# 627      Sunnyvale                 NaN      Mobius Microsystems       1  ...
# 811       Campbell                 NaN  Anchor Bay Technologies       1  ...
# 840  San Francisco                 NaN                 about.me       1  ...
# 905       San Jose   San Jose CA 95110        Broadway Networks       0  ...
#
#     object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 60    c:35157      0         0          0           1           0           0
# 128   c:43875      1         0          0           1           0           0
# 350   c:26390      0         1          0           0           0           0
# 371   c:47601      0         0          0           0           0           1
# 542   c:17252      0         0          1           0           0           0
# 558    c:2245      0         1          0           0           0           0
# 579    c:1967      1         0          0           0           1           0
# 618   c:32144      0         1          0           0           0           0
# 627   c:17508      0         0          1           1           0           0
# 811   c:26666      1         0          1           0           0           0
# 840   c:38337      1         0          0           0           0           0
# 905   c:25756      1         0          0           0           0           0
#
#      avg_participants  is_top500    status
# 60                2.0          1    closed
# 128               3.0          1    closed
# 350               1.0          0    closed
# 371               5.0          1  acquired
# 542               1.0          0    closed
# 558               1.0          0    closed
# 579               2.0          1  acquired
# 618               1.0          0    closed
# 627               3.0          1  acquired
# 811               3.0          1  acquired
# 840               4.0          1  acquired
# 905               1.0          0    closed
#
# [12 rows x 49 columns]

# %% [markdown]
# 12 values contain negative age_last_milestone_year values and they will be considered for removal during the data cleaning process.

# %% [markdown]
# Satate consistency: state_code vs one-hot flags

# %%
"""
check
if only each starup has only one state flag = 1
i.e state_code == 'CA' -> is_CA == 1 and only is_CA and so on

"""
# Out:
# "\ncheck\nif only each starup has only one state flag = 1\ni.e state_code == 'CA' -> is_CA == 1 and only is_CA and so on\n\n"

# %%
#checking if there's only one state flag for each startup coming from state_code column transformation

state_flags = ['is_CA',
'is_NY',
'is_MA',
'is_TX',
'is_otherstate']

states_sum = startups[state_flags].sum(axis=1)
states_violations = (states_sum != 1).sum()
print(states_violations)

#looking up this one row
startups_w_many_states = startups[startups[state_flags].sum(axis=1) != 1]
startups_w_many_states[state_flags]
# Out:
# 1
#      is_CA  is_NY  is_MA  is_TX  is_otherstate
# 515      0      0      0      0              0

# %% [markdown]
# There's one startup that is not assigned to any state. This case will also be considered durign the data cleaning stage.

# %%
#checking if state_flags were generated correctly, i.e if state_code = "CA" == is_CA = 1
ca_mismatch = (startups["state_code"] == "CA") & (startups["is_CA"] != 1)
ny_mismatch = (startups["state_code"] == "NY") & (startups["is_NY"] !=1)
ma_mismatch = (startups["state_code"] == "MA") & (startups["is_MA"] != 1)
tx_mismatch = (startups["state_code"] == "TX") & (startups["is_TX"] != 1)
otherstate_mismatch = (startups["state_code"] == "otherstate") & (startups["is_otherstate"] != 1)

print(ca_mismatch.sum())
print(ny_mismatch.sum())
print(ma_mismatch.sum())
print(tx_mismatch.sum())
print(otherstate_mismatch.sum())

startups[ca_mismatch][["id", "name", "state_code"] + state_flags]
# Out:
# 1
# 0
# 0
# 0
# 0
#         id  name state_code  is_CA  is_NY  is_MA  is_TX  is_otherstate
# 515  c:856  Cuil         CA      0      0      0      0              0

# %% [markdown]
# There is one (same as the previous one) startup that returns 1 mismatch and is not assigned to any state but it looks like it should belong to CA.

# %% [markdown]
# State_code vs state_code.1

# %%
"""
check whether state_code = state_code.1 as it looks like export duplicate
"""
# Out:
# '\ncheck whether state_code = state_code.1 as it looks like export duplicate\n'

# %%
#checking if state_code is the same as state_code.1

check_mismatches = (startups["state_code"] != startups["state_code.1"])
check_mismatches

startups[check_mismatches][["state_code", "state_code.1", "id"]]
# Out:
#     state_code state_code.1     id
# 515         CA          NaN  c:856

# %% [markdown]
# The column state_code.1 is almost identical with column state_code. There is only one inconsistency between these two columns. It indicates that state_code.1 is possibly a processing artifact. Tnis column does not add any additional value to the dataset and will be consider for removal in upcoming steps.

# %% [markdown]
# Funding logic consistency

# %%
"""

funding_total_usd ≥ 0
funding_rounds ≥ 0
jeśli funding_rounds == 0 → brak has_roundA–D
jeśli has_roundB == 1 → logicznie has_roundA == 1

"""
# Out:
# '\n\nfunding_total_usd ≥ 0\nfunding_rounds ≥ 0\njeśli funding_rounds == 0 → brak has_roundA–D\njeśli has_roundB == 1 → logicznie has_roundA == 1\n\n'

# %%
#checking if funding_total_usd >= 0
funding_total_check = (startups["funding_total_usd"] <= 0).sum()
print(funding_total_check)
# Out:
# 0

# %% [markdown]
# There are no rows where funding_total_usd is less than or equal to zero, indicaiting that no invalid values were detected.

# %%
#checking if funding_rounds >= 0

round_flags = ["has_roundA", "has_roundB", "has_roundC", "has_roundD"]
no_rounds = startups["funding_rounds"] == 0

flag_errors = startups[no_rounds & (startups[round_flags].sum(axis=1) > 1)]
flag_errors
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, state_code, latitude, longitude, zip_code, id, city, Unnamed: 6, name, labels, founded_at, closed_at, first_funding_at, last_funding_at, age_first_funding_year, age_last_funding_year, age_first_milestone_year, age_last_milestone_year, relationships, funding_rounds, funding_total_usd, milestones, state_code.1, is_CA, is_NY, is_MA, is_TX, is_otherstate, category_code, is_software, is_web, is_mobile, is_enterprise, is_advertising, is_gamesvideo, is_ecommerce, is_biotech, is_consulting, is_othercategory, object_id, has_VC, has_angel, has_roundA, has_roundB, has_roundC, has_roundD, avg_participants, is_top500, status]
# Index: []
#
# [0 rows x 49 columns]

# %% [markdown]
# There are no rows where funding_rounds is less than or equal to zero, indicating that no invalid values were detected.

# %%
#checking if there's NaN/0 for has_roundA-D if funding_rounds == 0

round_flags = ["has_roundA", "has_roundB", "has_roundC", "has_roundD"]
no_rounds = startups["funding_rounds"] == 0

no_rounds_flags = startups[no_rounds & startups[round_flags].sum(axis=1) > 1]
no_rounds_flags
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, state_code, latitude, longitude, zip_code, id, city, Unnamed: 6, name, labels, founded_at, closed_at, first_funding_at, last_funding_at, age_first_funding_year, age_last_funding_year, age_first_milestone_year, age_last_milestone_year, relationships, funding_rounds, funding_total_usd, milestones, state_code.1, is_CA, is_NY, is_MA, is_TX, is_otherstate, category_code, is_software, is_web, is_mobile, is_enterprise, is_advertising, is_gamesvideo, is_ecommerce, is_biotech, is_consulting, is_othercategory, object_id, has_VC, has_angel, has_roundA, has_roundB, has_roundC, has_roundD, avg_participants, is_top500, status]
# Index: []
#
# [0 rows x 49 columns]

# %% [markdown]
# There are no rows where the column funding_rounds == 0 and one of the round columns is equal to 1. No invalid input detected.

# %% [markdown]
# # Descriptive statistics

# %%
startups.shape
# Out:
# (923, 49)

# %% [markdown]
# The data seems to be high-dimensional - a small dataset with high number of variables. This combinattion increases the chance of overfitting and requires cateful validation and feature engineering.

# %%
startups[[
 "funding_total_usd",
 "funding_rounds",
 "avg_participants",
 "relationships",
 "milestones",
 "age_first_funding_year",
 "age_last_funding_year",
 "age_first_milestone_year",
 "age_last_milestone_year",
 "latitude",
 "longitude"
]].describe()
# Out:
#        funding_total_usd  funding_rounds  avg_participants  relationships  \
# count       9.230000e+02      923.000000        923.000000     923.000000
# mean        2.541975e+07        2.310943          2.838586       7.710726
# std         1.896344e+08        1.390922          1.874601       7.265776
# min         1.100000e+04        1.000000          1.000000       0.000000
# 25%         2.725000e+06        1.000000          1.500000       3.000000
# 50%         1.000000e+07        2.000000          2.500000       5.000000
# 75%         2.472500e+07        3.000000          3.800000      10.000000
# max         5.700000e+09       10.000000         16.000000      63.000000
#
#        milestones  age_first_funding_year  age_last_funding_year  \
# count  923.000000              923.000000             923.000000
# mean     1.841820                2.235630               3.931456
# std      1.322632                2.510449               2.967910
# min      0.000000               -9.046600              -9.046600
# 25%      1.000000                0.576700               1.669850
# 50%      2.000000                1.446600               3.528800
# 75%      3.000000                3.575350               5.560250
# max      8.000000               21.895900              21.895900
#
#        age_first_milestone_year  age_last_milestone_year    latitude  \
# count                771.000000               771.000000  923.000000
# mean                   3.055353                 4.754423   38.517442
# std                    2.977057                 3.212107    3.741497
# min                  -14.169900                -7.005500   25.752358
# 25%                    1.000000                 2.411000   37.388869
# 50%                    2.520500                 4.476700   37.779281
# 75%                    4.686300                 6.753400   40.730646
# max                   24.684900                24.684900   59.335232
#
#         longitude
# count  923.000000
# mean  -103.539212
# std     22.394167
# min   -122.756956
# 25%   -122.198732
# 50%   -118.374037
# 75%    -77.214731
# max     18.057121

# %% [markdown]
# *   What is concering are the negative minimum values in the age-related columns. These values are logically incosistent and were not mentioned in the dataset description. However, it might indicate that these fundings were recorded before company was officially founded. These inconsistencies are only flagged here and will be addressed in the data cleaning phase.
#
#
# *   The funding_total_usd variable exhibits strong right skewness: the mean substantially exceeds the median.This indicates a heavy-tailed distribution driven by a small number of start ups with exceptionally well fundings.
#
#
# * The extremely high maximum values observed for funding_total_usd, funding_rounds, relationships and milestones suggest the presence of of structural outlier. These vealues lie far above the 75th percentile and reflect heavy-tailed nature of this dataset.

# %%
"""
-Histograms and boxplots for key numerical features to understand shape, spread, and the presence of heavy tails or extreme values.
-Frequency counts and percentage breakdowns of major categorical variables (e.g., state, status, category) to identify dominant and rare categories.
-Correlation matrix for numeric features to detect strongly correlated or redundant variables.
"""
# Out:
# '\n\n-Summary metrics (count, mean, std, min, max, quartiles) used to identify skewness, outliers, zero‑inflated variables, and scale differences.\n-Histograms and boxplots for key numerical features to understand shape, spread, and the presence of heavy tails or extreme values.\n-Frequency counts and percentage breakdowns of major categorical variables (e.g., state, status, category) to identify dominant and rare categories.\n-Correlation matrix for numeric features to detect strongly correlated or redundant variables.\n-High‑level observations summarizing skewed variables, imbalanced categories, zero‑dominant metrics, scale inconsistencies, and initial hypotheses for future feature engineering.\n\n'

# %%
# -distribution of numeric columns

categorical_cols = startups.select_dtypes(include=['object']).columns

for col in categorical_cols:
  display(startups[col].value_counts())
  display(startups[col].value_counts(normalize=True) * 100)

  sns.countplot(y=startups[col], order=startups[col].value_counts().index[:10])
  plt.title(f"Top 10 categories: {col}")
  plt.show()
# Out:
# state_code
# CA    488
# NY    106
# MA     83
# WA     42
# TX     42
# CO     19
# IL     18
# PA     17
# VA     13
# GA     11
# NC      7
# OR      7
# NJ      7
# MD      7
# FL      6
# OH      6
# MN      5
# CT      4
# DC      4
# UT      3
# TN      3
# RI      3
# MI      3
# KY      2
# ME      2
# NH      2
# MO      2
# IN      2
# NV      2
# AZ      2
# WV      1
# NM      1
# ID      1
# AR      1
# WI      1
# Name: count, dtype: int64
# state_code
# CA    52.871073
# NY    11.484290
# MA     8.992416
# WA     4.550379
# TX     4.550379
# CO     2.058505
# IL     1.950163
# PA     1.841820
# VA     1.408451
# GA     1.191766
# NC     0.758397
# OR     0.758397
# NJ     0.758397
# MD     0.758397
# FL     0.650054
# OH     0.650054
# MN     0.541712
# CT     0.433369
# DC     0.433369
# UT     0.325027
# TN     0.325027
# RI     0.325027
# MI     0.325027
# KY     0.216685
# ME     0.216685
# NH     0.216685
# MO     0.216685
# IN     0.216685
# NV     0.216685
# AZ     0.216685
# WV     0.108342
# NM     0.108342
# ID     0.108342
# AR     0.108342
# WI     0.108342
# Name: proportion, dtype: float64
# zip_code
# 94107    30
# 94105    23
# 95054    20
# 94103    19
# 94043    18
#          ..
# 75244     1
# 2466      1
# 85284     1
# 43607     1
# 92008     1
# Name: count, Length: 382, dtype: int64
# zip_code
# 94107    3.250271
# 94105    2.491874
# 95054    2.166847
# 94103    2.058505
# 94043    1.950163
#            ...
# 75244    0.108342
# 2466     0.108342
# 85284    0.108342
# 43607    0.108342
# 92008    0.108342
# Name: proportion, Length: 382, dtype: float64
# id
# c:28482    2
# c:14993    1
# c:1223     1
# c:55421    1
# c:28403    1
#           ..
# c:282      1
# c:6340     1
# c:9599     1
# c:63621    1
# c:24029    1
# Name: count, Length: 922, dtype: int64
# id
# c:28482    0.216685
# c:14993    0.108342
# c:1223     0.108342
# c:55421    0.108342
# c:28403    0.108342
#              ...
# c:282      0.108342
# c:6340     0.108342
# c:9599     0.108342
# c:63621    0.108342
# c:24029    0.108342
# Name: proportion, Length: 922, dtype: float64
# city
# San Francisco    128
# New York          91
# Mountain View     47
# Palo Alto         35
# Austin            27
#                 ...
# Idaho Falls        1
# Avon               1
# Little Rock        1
# Lisle              1
# Middleton          1
# Name: count, Length: 221, dtype: int64
# city
# San Francisco    13.867822
# New York          9.859155
# Mountain View     5.092091
# Palo Alto         3.791983
# Austin            2.925244
#                    ...
# Idaho Falls       0.108342
# Avon              0.108342
# Little Rock       0.108342
# Lisle             0.108342
# Middleton         0.108342
# Name: proportion, Length: 221, dtype: float64
# Unnamed: 6
# San Francisco CA 94105     12
# New York NY 10011           8
# San Francisco CA 94103      8
# New York NY 10003           8
# Santa Clara CA 95054        8
#                            ..
# Aliso Viejo CA 92656        1
# Portland OR 97224           1
# Palo Alto CA 94301-1705     1
# Little Rock AR 72201        1
# Houston TX 77046            1
# Name: count, Length: 252, dtype: int64
# Unnamed: 6
# San Francisco CA 94105     2.790698
# New York NY 10011          1.860465
# San Francisco CA 94103     1.860465
# New York NY 10003          1.860465
# Santa Clara CA 95054       1.860465
#                              ...
# Aliso Viejo CA 92656       0.232558
# Portland OR 97224          0.232558
# Palo Alto CA 94301-1705    0.232558
# Little Rock AR 72201       0.232558
# Houston TX 77046           0.232558
# Name: proportion, Length: 252, dtype: float64
# name
# Redwood Systems      2
# Exit41               1
# SezWho               1
# Jobs2Web             1
# HighlightCam         1
#                     ..
# Kiptronic            1
# Cozi Group           1
# Likewise Software    1
# Lifestander          1
# Blip                 1
# Name: count, Length: 922, dtype: int64
# name
# Redwood Systems      0.216685
# Exit41               0.108342
# SezWho               0.108342
# Jobs2Web             0.108342
# HighlightCam         0.108342
#                        ...
# Kiptronic            0.108342
# Cozi Group           0.108342
# Likewise Software    0.108342
# Lifestander          0.108342
# Blip                 0.108342
# Name: proportion, Length: 922, dtype: float64
# closed_at
# 6/1/2013     25
# 1/1/2012     24
# 7/1/2013     15
# 5/1/2013     12
# 1/1/2011      8
#              ..
# 4/17/2009     1
# 11/5/2010     1
# 12/2/2012     1
# 6/25/2008     1
# 6/17/2012     1
# Name: count, Length: 202, dtype: int64
# closed_at
# 6/1/2013     7.462687
# 1/1/2012     7.164179
# 7/1/2013     4.477612
# 5/1/2013     3.582090
# 1/1/2011     2.388060
#                ...
# 4/17/2009    0.298507
# 11/5/2010    0.298507
# 12/2/2012    0.298507
# 6/25/2008    0.298507
# 6/17/2012    0.298507
# Name: proportion, Length: 202, dtype: float64
# state_code.1
# CA    487
# NY    106
# MA     83
# WA     42
# TX     42
# CO     19
# IL     18
# PA     17
# VA     13
# GA     11
# NC      7
# OR      7
# NJ      7
# MD      7
# FL      6
# OH      6
# MN      5
# CT      4
# DC      4
# UT      3
# TN      3
# RI      3
# MI      3
# KY      2
# ME      2
# NH      2
# MO      2
# IN      2
# NV      2
# AZ      2
# WV      1
# NM      1
# ID      1
# AR      1
# WI      1
# Name: count, dtype: int64
# state_code.1
# CA    52.819957
# NY    11.496746
# MA     9.002169
# WA     4.555315
# TX     4.555315
# CO     2.060738
# IL     1.952278
# PA     1.843818
# VA     1.409978
# GA     1.193059
# NC     0.759219
# OR     0.759219
# NJ     0.759219
# MD     0.759219
# FL     0.650759
# OH     0.650759
# MN     0.542299
# CT     0.433839
# DC     0.433839
# UT     0.325380
# TN     0.325380
# RI     0.325380
# MI     0.325380
# KY     0.216920
# ME     0.216920
# NH     0.216920
# MO     0.216920
# IN     0.216920
# NV     0.216920
# AZ     0.216920
# WV     0.108460
# NM     0.108460
# ID     0.108460
# AR     0.108460
# WI     0.108460
# Name: proportion, dtype: float64
# category_code
# software            153
# web                 144
# mobile               79
# enterprise           73
# advertising          62
# games_video          52
# semiconductor        35
# biotech              34
# network_hosting      34
# hardware             27
# public_relations     25
# ecommerce            25
# cleantech            23
# analytics            19
# security             19
# social               14
# search               12
# messaging            11
# other                11
# news                  8
# travel                8
# fashion               8
# photo_video           7
# medical               7
# music                 6
# finance               6
# education             4
# real_estate           3
# consulting            3
# health                3
# automotive            2
# transportation        2
# manufacturing         2
# hospitality           1
# sports                1
# Name: count, dtype: int64
# category_code
# software            16.576381
# web                 15.601300
# mobile               8.559047
# enterprise           7.908992
# advertising          6.717226
# games_video          5.633803
# semiconductor        3.791983
# biotech              3.683640
# network_hosting      3.683640
# hardware             2.925244
# public_relations     2.708559
# ecommerce            2.708559
# cleantech            2.491874
# analytics            2.058505
# security             2.058505
# social               1.516793
# search               1.300108
# messaging            1.191766
# other                1.191766
# news                 0.866739
# travel               0.866739
# fashion              0.866739
# photo_video          0.758397
# medical              0.758397
# music                0.650054
# finance              0.650054
# education            0.433369
# real_estate          0.325027
# consulting           0.325027
# health               0.325027
# automotive           0.216685
# transportation       0.216685
# manufacturing        0.216685
# hospitality          0.108342
# sports               0.108342
# Name: proportion, dtype: float64
# object_id
# c:28482    2
# c:14993    1
# c:1223     1
# c:55421    1
# c:28403    1
#           ..
# c:282      1
# c:6340     1
# c:9599     1
# c:63621    1
# c:24029    1
# Name: count, Length: 922, dtype: int64
# object_id
# c:28482    0.216685
# c:14993    0.108342
# c:1223     0.108342
# c:55421    0.108342
# c:28403    0.108342
#              ...
# c:282      0.108342
# c:6340     0.108342
# c:9599     0.108342
# c:63621    0.108342
# c:24029    0.108342
# Name: proportion, Length: 922, dtype: float64
# status
# acquired    597
# closed      326
# Name: count, dtype: int64
# status
# acquired    64.68039
# closed      35.31961
# Name: proportion, dtype: float64

# %% [markdown]
# *   Around 50% of all the startups in the dataset are located in California, which represents an exceptionally large share compared to the other states.
# *   The distribution of the city variable is heavily concentrated in small number of major tech hubs - San Francisco, New York and Mountain View. This indicates that the dataset is skewed toward top innovation ecosystems.

# %%
# -distribution of categorical columns

numerical_cols = startups.select_dtypes(include=['object']).columns

for col in numerical_cols:
  display(startups[col].value_counts())
  display(startups[col].value_counts(normalize=True) * 100)

  sns.countplot(y=startups[col], order=startups[col].value_counts().index[:10])
  plt.title(f"Top 10 categories: {col}")
  plt.show()

# %%
# -distribution of datetime columns

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# # Bivariate relationships (high level)

# %% [markdown]
# # Outliers & anomalies

# %% [markdown]
# # Summary: data issues to fix in the next step
